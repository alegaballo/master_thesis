# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('train_hist.pkl','rb') as f:
    th = pickle.load(f)
with open('test_metrics.pkl', 'rb') as f:
    tm = pickle.load(f)

# %%
sns.set_style('ticks')
plt.figure(figsize=(12,7))
#plt.subplot(121)
plt.xlabel('Epoch',fontsize=18)
plt.ylabel('Accuracy',fontsize=18)
plt.grid(False)
#plt.title('Model accuracy',fontsize=18)
plt.plot(th[0]['categorical_accuracy'])
plt.plot(th[0]['val_categorical_accuracy'],'--')
plt.plot(th[1]['categorical_accuracy'], '-.')
plt.plot(th[1]['val_categorical_accuracy'], ':')
plt.legend(['Training accuracy', 'Validation accuracy','Training accuracy with normalization', 
            'Validation accuracy with normalization'], fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.despine()

# plt.subplot(122)
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.grid(False)
# plt.title('Model loss')
# plt.plot(th[0]['loss'])
# plt.plot(th[0]['val_loss'], '--')
# plt.plot(th[1]['loss'], '-.')
# plt.plot(th[1]['val_loss'], ':')
# plt.legend(['Training loss', 'Validation loss','Training loss with normalization', 'Validation loss with normalization'], loc='upper right')
#plt.savefig('normalization_acc_cmp.pdf', bbox='tight')
plt.savefig('normalization_acc_cmp.eps', bbox_inches='tight',format='eps', dpi=500, transparent=True)

plt.show()
